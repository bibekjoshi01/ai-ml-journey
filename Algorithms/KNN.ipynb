# %%
import pandas as pd

# %%
df = pd.read_csv("./data.csv")
df = df.drop(['id', 'Unnamed: 32'], axis=1)
df.sample(10)
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 261         M       17.350         23.06          111.00      933.1
# 247         B       12.890         14.11           84.95      512.2
# 297         M       11.760         18.14           75.00      431.1
# 555         B       10.290         27.61           65.67      321.4
# 1           M       20.570         17.77          132.90     1326.0
# 186         M       18.310         18.58          118.60     1041.0
# 380         B       11.270         12.96           73.16      386.3
# 387         B       13.880         16.16           88.37      596.6
# 410         B       11.360         17.57           72.49      399.8
# 504         B        9.268         12.87           61.49      248.7
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 261          0.08662           0.06290         0.02891             0.028370
# 247          0.08760           0.13460         0.13740             0.039800
# 297          0.09968           0.05914         0.02685             0.035150
# 555          0.09030           0.07658         0.05999             0.027380
# 1            0.08474           0.07864         0.08690             0.070170
# 186          0.08588           0.08468         0.08169             0.058140
# 380          0.12370           0.11110         0.07900             0.055500
# 387          0.07026           0.04831         0.02045             0.008507
# 410          0.08858           0.05313         0.02783             0.021000
# 504          0.16340           0.22390         0.09730             0.052520
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 261         0.1564  ...         19.85          31.47           128.20
# 247         0.1596  ...         14.39          17.70           105.00
# 297         0.1619  ...         13.36          23.39            85.10
# 555         0.1593  ...         10.84          34.91            69.57
# 1           0.1812  ...         24.99          23.41           158.80
# 186         0.1621  ...         21.31          26.36           139.20
# 380         0.2018  ...         12.84          20.53            84.93
# 387         0.1607  ...         15.51          19.97            99.66
# 410         0.1601  ...         13.05          36.32            85.07
# 504         0.2378  ...         10.28          16.38            69.05
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 261      1218.0           0.12400            0.14860           0.1211
# 247       639.1           0.12540            0.58490           0.7727
# 297       553.6           0.11370            0.07974           0.0612
# 555       357.6           0.13840            0.17100           0.2000
# 1        1956.0           0.12380            0.18660           0.2416
# 186      1410.0           0.12340            0.24450           0.3538
# 380       476.1           0.16100            0.24290           0.2247
# 387       745.3           0.08484            0.12330           0.1091
# 410       521.3           0.14530            0.16220           0.1811
# 504       300.2           0.19020            0.34410           0.2099
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 261               0.08235          0.2452                  0.06515
# 247               0.15610          0.2639                  0.11780
# 297               0.07160          0.1978                  0.06915
# 555               0.09127          0.2226                  0.08283
# 1                 0.18600          0.2750                  0.08902
# 186               0.15710          0.3206                  0.06938
# 380               0.13180          0.3343                  0.09215
# 387               0.04537          0.2542                  0.06623
# 410               0.08698          0.2973                  0.07745
# 504               0.10250          0.3038                  0.12520
#
# [10 rows x 31 columns]

# %%
df.shape
# Out:
# (569, 31)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:, 1:], df.iloc[:, 0], test_size=0.2, random_state=2)

# %%
X_train.head()
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 560        14.05         27.15           91.38      600.4          0.09929
# 428        11.13         16.62           70.47      381.1          0.08151
# 198        19.18         22.49          127.50     1148.0          0.08523
# 203        13.81         23.75           91.56      597.8          0.13230
# 41         10.95         21.35           71.90      371.1          0.12270
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 560           0.11260         0.04462              0.04304         0.1537
# 428           0.03834         0.01369              0.01370         0.1511
# 198           0.14280         0.11140              0.06772         0.1767
# 203           0.17680         0.15580              0.09176         0.2251
# 41            0.12180         0.10440              0.05669         0.1895
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 560                 0.06171  ...         15.30          33.17
# 428                 0.06148  ...         11.68          20.29
# 198                 0.05529  ...         23.36          32.06
# 203                 0.07421  ...         19.20          41.85
# 41                  0.06870  ...         12.84          35.34
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 560           100.20       706.7            0.1241            0.22640
# 428            74.35       421.1            0.1030            0.06219
# 198           166.40      1688.0            0.1322            0.56010
# 203           128.50      1153.0            0.2226            0.52090
# 41             87.22       514.0            0.1909            0.26980
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 560           0.1326               0.10480          0.2250
# 428           0.0458               0.04044          0.2383
# 198           0.3865               0.17080          0.3193
# 203           0.4646               0.20130          0.4432
# 41            0.4023               0.14240          0.2964
#
#      fractal_dimension_worst
# 560                  0.08321
# 428                  0.07083
# 198                  0.09221
# 203                  0.10860
# 41                   0.09606
#
# [5 rows x 30 columns]

# %%
X_train.shape
# Out:
# (455, 30)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-0.01330339,  1.7757658 , -0.01491962, ..., -0.13236958,
#         -1.08014517, -0.03527943],
#        [-0.8448276 , -0.6284278 , -0.87702746, ..., -1.11552632,
#         -0.85773964, -0.72098905],
#        [ 1.44755936,  0.71180168,  1.47428816, ...,  0.87583964,
#          0.4967602 ,  0.46321706],
#        ...,
#        [-0.46608541, -1.49375484, -0.53234924, ..., -1.32388956,
#         -1.02997851, -0.75145272],
#        [-0.50025764, -1.62161319, -0.527814  , ..., -0.0987626 ,
#          0.35796577, -0.43906159],
#        [ 0.96060511,  1.21181916,  1.00427242, ...,  0.8956983 ,
#         -1.23064515,  0.50697397]], shape=(455, 30))

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
from sklearn.metrics import accuracy_score

y_pred = knn.predict(X_test)

accuracy_score(y_test, y_pred)
# Out:
# 0.9912280701754386

# %%
# Let's try with different k values

scores = []
k_values = list(range(1, 16))

for i in k_values:
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    scores.append(accuracy_score(y_test, y_pred))

# %%
import matplotlib.pyplot as plt

plt.plot(k_values, scores, marker='o')
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('Accuracy')
plt.title('KNN Accuracy for Different k values')
plt.grid(True)
plt.show()
